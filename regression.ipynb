# %% [markdown]
# <a href="https://colab.research.google.com/github/Konwik/MLDLTorch/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imported required stuff
import torch
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import csv
import pandas as pd

# %%
#downladed the dataset
import kagglehub

path = kagglehub.dataset_download("abhishek14398/salary-dataset-simple-linear-regression")

print("Path to dataset files:", path)
# path = /kaggle/input/salary-dataset-simple-linear-regression
# Out:
# Using Colab cache for faster access to the 'salary-dataset-simple-linear-regression' dataset.
# Path to dataset files: /kaggle/input/salary-dataset-simple-linear-regression

# %%
df = pd.read_csv("/kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv")
print(df.head())
#printed staring elements of data
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
train_data = (df.sample(frac=0.8, random_state=0))
print(train_data.head())
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 2            2              1.6   37732.0
# 28          28             10.4  122392.0
# 13          13              4.2   57082.0
# 10          10              4.0   63219.0
# 26          26              9.6  116970.0

# %%
plt.scatter(df["YearsExperience"], df["Salary"])
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
#ploted data
# Out:
# Text(0, 0.5, 'Salary')
